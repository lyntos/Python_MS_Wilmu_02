# %% [markdown]
# <a href="https://colab.research.google.com/github/lyntos/Python_MS_Wilmu_02/blob/main/01_%20Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %load /content/copy_of_week_1_exercises_anderson_robert-1.py
#2.1(What does this code do?) Create the variables x = 2 and y = 3, then determine what each of the following statements displays:
'''
    a.print('x =', x)
    b.print('Value of', x, '+', x, 'is', (x + x))
    c.print('x =')
    d.print((x + y), '=', (y + x))
'''

#declare variables from the statement above
x = 2
y = 3

# print a-d to determine output
print('x =', x)
print('Value of', x, '+', x, 'is', (x + x))
print('x =')
print((x + y), '=', (y + x))

'''each of these statements displays the following:
x = 2
Value of 2 + 2 is 4
x =
5 = 5
'''

# 2.2(What’s wrong with this code?) The following code should read an integer into the variable rating:
# rating = input('Enter an integer rating between 1 and 10')

'''Answer: there are at least two problems with this code: 1) it does not cast the user input to an integer,
and 2) it does not limit the user input to the integers 1 through 10 '''

#a more complete solution would be:
#prompt user for an integer input from 1 - 10
proceed = True
while proceed == True:
    rating = int(input('Enter an integer rating between 1 and 10: '))
    if 1 <= int(rating) <= 10:
        print('Correct')
        proceed_input = input('Would you like to continue? (y/n): ').lower()
        if proceed_input != 'y':
            proceed = False
    else:
        print('Out of range. Enter a number from 1 through 10')
        proceed_input = input('Would you like to continue? (y/n): ').lower()
        if proceed_input != 'y':
            proceed = False
#needs a try-catch block

'''
2.3(Fill in the missing code) Replace *** in the following code with a statement that will print a message like 'Congratulations! Your grade of 91 earns you an A in this course'. Your statement should print the value stored in the variable grade:

    if grade >= 90:

            ***
'''
grade = input('Enter your final grade: ')
if int(grade) >= 90:
    print('Congratulations! Your grade of', grade, 'earns you an A in this course')
else:
    print('Sorry. Your grade of', grade, 'did not earn you an A in this course')

#2.4(Arithmetic) For each of the arithmetic operators +, -, *, /, // and **, display the value of an expression with 27.5 as the left operand and 2 as the right operand.

x = 27.5
y = 2

print(x+y)
print(x-y)
print(x*y)
print(x/y)
print(x//y)
print(x**y)

#2.5(Circle Area, Diameter and Circumference) For a circle of radius 2, display the diameter, circumference and area. Use the value 3.14159 for π. Use the following formulas (r is the radius): diameter = 2r, circumference = 2πr and area = πr2. [In a later chapter, we’ll introduce Python’s math module which contains a higher-precision representation of π.]
r = 2
π = 3.14159

print('Diameter =', 2*r)
print('Circumference =', 2*π*r)
print('Area =', π*(r**2))

#2.6 (Odd or Even) Use if statements to determine whether an integer is odd or even.
#[Hint: Use the remainder operator. An even number is a multiple of 2. Any multiple of 2 leaves a remainder of 0 when divided by 2.]

x = int(input('Enter a number '))

#divide input by 2 - remainder of 0 means even
if x==0:
  print(x, 'is zero')
elif x % 2 == 0:
  print(x,'is even')
else:
  print(x, 'is odd')

'''2.7(Multiples) Use if statements to determine whether
1024 is a multiple of 4
and whether 2 is a multiple of 10. (Hint: Use the remainder operator.)
'''
x = 1024
y = 2

if x % 4 == 0:
  print(x ,'is a multiple of 4')
else:
  print(x, 'is not a multiple of 4')

if y % 10 == 0:
  print(y ,'is a multiple of 10')
else:
  print(y, 'is not a multiple of 10')

'''2.8(Table of Squares and Cubes)
Write a script that calculates the squares and cubes of the numbers from 0 to 5.
Print the resulting values in table format, as shown below.
Use the tab escape sequence to achieve the three-column output.'''

#print table with only tab formatting
print(str('{n}\t{s}\t{c}').format(n = "Number", s = "Square", c = "Cube"))
for i in range (6):
  print('{n}\t{s}\t{c}'.format(n = i, s = i**2, c = i**3))

#print table output with tabs and right alignment
print(str('{n:>8}\t{s:>8}\t{c:>8}').format(n = "Number", s = "Square", c = "Cube"))
for i in range (6):
  print('{n:>8}\t{s:>8}\t{c:>8}'.format(n = i, s = i**2, c = i**3))

# 2.9 Display the integer equivalents of C D b c d 0 1 2 * +  and the space
# character.

list1 = ['C', 'D', 'b', 'c', 'd', '0', '1', '2', '*', '+', ' ']
print('characters given: ',list1)
list2 =[]

for i in list1:
  list2.append(ord(i))

print('integer equivalents: ', list2)

'''2.10(Arithmetic, Smallest and Largest) Write a script that inputs three integers from the user.
Display the sum, average, product, smallest and largest of the numbers.
Note that each of these is a reduction in functional-style programming.'''
from statistics import  mean
from math import prod
m=0
n=0
o=0
print('Please provide three numbers and I will tell you their sum, average, product, smallest and largest')
list1 = []
list1.append(int(input('Enter first number: ')))
list1.append(int(input('Enter second number: ')))
list1.append(int(input('Enter third number: ')))

print("you have entered: ", list1)

#get the min and max valie from the list
smallest = min(list1)
largest = max(list1)

#print the desired output
print('The sum is: ',sum(list1))
print('The average is: ', mean(list1))
print('The product is: ',prod(list1))
print("The smallest is: ", smallest)
print("The largest is: ", largest)

'''2.11 (Separating the Digits in an Integer) Write a script that inputs a five-digit integer from the user.
Separate the number into its individual digits.
Print them separated by three spaces each. For example, if the user types in the number 42339, the script should print 4  2  3  3  9
Assume that the user enters the correct number of digits.
Use both the floor division and remainder operations to “pick off” each digit.'''

x = int(input('Enter a five digit number: '))

digit1 = x//10000
digit2 = (x%10000)//1000
digit3 = ((x%10000)%1000)//100
digit4 = (((x%10000)%1000)%100)//10
digit5 = ((((x%10000)%1000)%100)%10)

print("{a: <3}{b: <3}{c: <3}{d: <3}{e: <3}".format(a = digit1, b = digit2, c = digit3, d = digit4, e = digit5))

'''2.12
(7% Investment Return)
Some investment advisors say that it’s reasonable to expect a  return over the long term in the stock market.
Assuming that you begin with  and leave your money invested,
calculate and display how much money you’ll have after 10, 20 and 30 years.
Use the following formula for determining these amounts:
a=p(1+r)^n
                where
                  p is the original amount invested (i.e., the principal of ),
                  r is the annual rate of return (),
                  n is the number of years ( or ) and
                  a is the amount on deposit at the end of the nth year.
'''

n = [10, 20, 30]
p = 1000
r = 0.07
a = 0

for i in n:
  a = p*(1+r)**i
  print('After', i, 'years you will have $', round(a,2))

'''2.13(How Big Can Python Integers Be?) We’ll answer this question later in the book.
For now, use the exponentiation operator  with large and very large exponents to produce some huge integers and assign those to the variable
to see if Python accepts them. Did you find any integer value that Python won’t accept?'''

x = 2**1500
print(x)

#answer:
#ValueError: Exceeds the limit (4300 digits) for integer string conversion; use sys.set_int_max_str_digits() to increase the limit

'''
2.14(Target Heart-Rate Calculator) While exercising,
you can use a heart-rate monitor to see that your heart rate stays within a safe range suggested by your doctors and trainers.
According to the American Heart Association (AHA) (), the formula for calculating your maximum heart rate in beats per minute is 220 your age in years.
Your target heart rate is  of your maximum heart rate. Write a script that prompts for and inputs the user’s age and calculates and displays the user’s maximum heart rate
and the range of the user’s target heart rate. [These formulas are estimates provided by the AHA;
maximum and target heart rates may vary based on the health, fitness and gender of the individual.
Always consult a physician or qualified healthcare professional before beginning or modifying an exercise program.]'''

age = int(input("Enter your age "))

maxheartrate = 220-age
targetmin = round(maxheartrate * 0.5)
targetmax = round(maxheartrate * 0.85)

print('Your maximum heart rate is', maxheartrate)
print('Your target heart rate is between', targetmin, 'and', targetmax)
print("DISCLAIMER:\nThese formulas are estimates provided by the AHA;\n maximum and target heart rates may vary based on the health, fitness and gender of the individual.\n Always consult a physician or qualified healthcare professional before beginning or modifying an exercise program.")

'''2.15(Sort in Ascending Order) Write a script that inputs three different floating-point numbers from the user.
Display the numbers in increasing order.
Recall that an if statement’s suite can contain more than one statement.
Prove that your script works by running it on all six possible orderings of the numbers.
Does your script work with duplicate numbers?
[This is challenging. In later chapters you’ll do this more conveniently and with many more numbers.]'''

a = float(input('Enter first number '))
b = float(input('Enter second number '))
c = float(input('Enter third number '))

if a < b < c:
  print(a, b, c)
elif a < c < b:
  print(a, c, b)
elif b < a < c:
  print(b, a, c)
elif b < c < a:
  print(b, c, a)
elif c < a < b:
  print(c, a, b)
else:
  print(c, b, a)

'''3.1 Modify the script of Fig. 3.3. to validate its inputs.
For any input, if the value entered is other than 1 or 2, keep looping until the user enters a correct value.
Use one counter to keep track of the number of passes,
then calculate the number of failures after all the user’s inputs have been received.'''

'''provided code
passes = 0
failures = 0

for student in range(10):
    result = int(input('Enter result (1=pass, 2=fail): '))

    if result == 1:
        passes = passes + 1
    else:
        failures = failures + 1

print('Passed:', passes)
print('Failed:', failures)

if passes > 8:
    print('Bonus to instructor')
'''

#modified code

#instantiate variables
passes = 0
failures = 0

# process n students, validate input for 1 or 2
attempts = 10
totalattempts = 0

while attempts > 0:
    result = int(input('Enter result (1=pass, 2=fail): '))

    if result == 1:
        passes += 1
        attempts -= 1
        totalattempts += 1
    elif result == 2:
        failures += 1
        attempts -= 1
        totalattempts += 1
    else:
        totalattempts += 1
        print('enter a 1 or 2')

print('Passed:', passes)
print('Failed:', failures)
print('Total Attempts', totalattempts)
print('Erroneous entries', totalattempts - 10)

if passes > 8:
    print('Bonus to instructor')

#3.2 3.2(What’s Wrong with This Code?)  What is wrong with the following code?
# a = b = 7
# print('a = ), a, '\nb = ', b)
#First, answer the question, then check your work in an IPython session.

'''
a = b = 7
print('a = ), a, '\nb = ', b)
'''

#variables should be declared separatey, the above code does not work becuase b has not been declared
a = 7
b = 7
'''
b = 7
a = b would also work'''

print('a = ', a, '\nb = ', b)

#3.3 What does this code do?

'''
for row in range(10):
  for column in range(10):
    print('<' if row % 2 == 1 else '>', en='')
  print()
'''
#print 10 rows, followed by a new line using print()
for row in range(10):
  #in each of the 10 rows, print 10 columns, '<' for odd rows and '>' for even rows; however, because it is using indexes 0-9, the order will appear flipped
  print(row) # to show row numbers, comment or delete for normal code
  for column in range(10):
    print('<' if row % 2 == 1 else '>', end='')
  #print a new line
  print()

'''3.4 fill in the missing code
for ***:
  for ***:
    print('@')
  print()

print so there are always two rows of seven '@' characters
'''
for row in range(2):
  for column in range(7):
    print('@', end='')
  print()

'''3.5(… Statements) Reimplement the script of Fig. 2.1 using three if…else statements rather than six  statements.
[Hint: For example, think of == and != as “opposite” tests.]
'''

 # fig02_01.py
"""Compare integers using if statements and comparison operators."""
'''
print('Enter two integers and I will tell you',
      'the relationships they satisfy.')

# read first integer
number1 = int(input('Enter first integer: '))

# read second integer
number2 = int(input('Enter second integer: '))

if number1 == number2:
    print(number1, 'is equal to', number2)

if number1 != number2:
    print(number1, 'is not equal to', number2)

if number1 < number2:
    print(number1, 'is less than', number2)

if number1 > number2:
    print(number1, 'is greater than', number2)

if number1 <= number2:
    print(number1, 'is less than or equal to', number2)

if number1 >= number2:
    print(number1, 'is greater than or equal to', number2)
'''

print('Enter two integers and I will tell you',
      'the relationships they satisfy.')

# read first integer
number1 = int(input('Enter first integer: '))

# read second integer
number2 = int(input('Enter second integer: '))

if number1 == number2:
    print(number1, 'is equal to', number2)
elif number1 < number2:
    print(number1, 'is less than', number2)
else:
    print(number1, 'is greater than', number2)

#3.6 Turing Test
'''The great British mathematician Alan Turing proposed a simple test to determine whether machines could exhibit intelligent behavior.
A user sits at a computer and does the same text chat with a human sitting at a computer and a computer operating by itself.
The user doesn’t know if the responses are coming back from the human or the independent computer.
If the user can’t distinguish which responses are coming from the human and which are coming from the computer,
then it’s reasonable to say that the computer is exhibiting intelligence.
Create a script that plays the part of the independent computer, giving its user a simple medical diagnosis.
The script should prompt the user with 'What is your problem?' When the user answers and presses Enter, the script should simply ignore the user’s input,
then prompt the user again with 'Have you ahd this problem before (yes or no)?' If the user enters 'yes', print 'Well, you have it again'
  If the user answers 'no', print 'Well, you have it now',
Would this conversation convince the user that the entity at the other end exhibited intelligent behavior? Why or why not?
'''

answer = input('What is your problem? ')
answer = input('Have you had this problem before (yes or no)? ')
if answer == 'yes':
  print('Well, you have it again')
else:
  print('Well, you have it now')

  #this could convince a user that the operator on the other side has intelligence, because it is "able to reason"; however, I believe they would need
  # significantly more prompts to reach a meaningful conclusion. Also, they would
  # think the doctor has no bedside manner

#3.7 (Table of squares and cubes - right-aligned)
#print table output with tabs and right alignment
print(str('{n:>6}\t{s:>6}\t{c:>6}').format(n = "Number", s = "Square", c = "Cube"))
for i in range (6):
  print('{n:>6}\t{s:>6}\t{c:>6}'.format(n = i, s = i**2, c = i**3), end='\n')

'''3.8 (Arithmetic, Smallest and Largest) In Exercise 2.10, you wrote a script that input three integers,
then displayed the sum, average, product, smallest and largest of those values.
Reimplement your script with a loop that inputs four integers.'''


from statistics import  mean
from math import prod
m=0
n=0
o=0
p=0

answers = 0;
list1 = []
print('Please provide three numbers and I will tell you their sum, average, product, smallest and largest')
while answers < 4:
  list1.append(int(input('Enter number ')))
  answers += 1

print("you have entered: ", list1)

#get the min and max valie from the list
smallest = min(list1)
largest = max(list1)

#print the desired output
print('The sum is: ',sum(list1))
print('The average is: ', mean(list1))
print('The product is: ',prod(list1))
print("The smallest is: ", smallest)
print("The largest is: ", largest)

'''(Separating the Digits in an Integer)
In Exercise 2.11, you wrote a script that separated a five-digit integer into its individual digits and displayed them.
Reimplement your script to use a loop that in each iteration “picks off” one digit (left to right) using the // and % operators, then displays that digit.
'''

x = int(input('Enter a five digit number: '))

i = 1
d = 10**(4)

while i < 6:
  n = x // d
  print('Digit', i, ': ', n)
  x %= d
  d //= 10
  i+=1

#digit1 = x//10000
#digit2 = (x%10000)//1000
#digit3 = ((x%10000)%1000)//100
#digit4 = (((x%10000)%1000)%100)//10
#digit5 = ((((x%10000)%1000)%100)%10)

#3.10(7% Investment Return)
#Reimplement Exercise 2.12 to use a loop that calculates and displays the amount of money you’ll have each year at the ends of years 1 through 30.
# enter formula variables
n = 30
p = 1000
r = 0.07
a = 0

#set loop variable
i = 1
#loop through to n years, print each year
while i <= n:
  a = p*(1+r)**(i)
  print('After', (i), 'years you will have $', round(a,2))
  i+=1

'''3.11(Miles Per Gallon)
Drivers are concerned with the mileage obtained by their automobiles.
One driver has kept track of several tankfuls of gasoline by recording miles driven and gallons used for each tankful.
Develop a sentinel-controlled-repetition script that prompts the user to input the miles driven and gallons used for each tankful.
The script should calculate and display the miles per gallon obtained for each tankful.
After processing all input information, the script should calculate and display the combined miles per gallon obtained for all tankfuls
(that is, total miles driven divided by total gallons used).'''

proceed = 'y'
miles = 0
gallons = 0

while proceed != 'n':
  miles += int(input('Enter miles driven: '))
  if isinstance(miles, int):
      gallons += int(input('Enter gallons used: '))
      if isinstance(gallons, int):
        proceed = input("Enter 'n' to quit")
        if(proceed == 'y'):
          continue
      elif(proceed == 'n'):
        break
      else:
        continue
  elif(proceed == 'n'):
    break
  else:
    continue

print('The combined miles per gallon obtained for all tankfuls is: ', round(miles/gallons, 1))
print('You used ', gallons, ' gallons')
print('You drove ', miles, ' miles')

#this script needs input validation like isinstance(miles, int), etc.

#3.17 3.17(Nested Loops)  Write a script that displays the following triangle patterns separately, one below the other.
#Separate each pattern from the next by one blank line.
#Use for loops to generate the patterns. Display all asterisks () with a single statement of the form print('*', end='')

#loop through using opposite ends of the range, each counting in opposite directions
#print left aligned, then right aligned, each column spaced by a tab
for i in range(1,11):
  a = '*'*i
  b = '*' *(11 - i)

  print("{a: <10}\t{b: <10}\t{c: >10}\t{d: >10}".format(a = a, b = b, c = b , d= a))

#3.18 - can't figure this one out
'''3.18(Challenge: Nested Looping)
Modify your script from Exercise 3.17 to display all four patterns side-by-side (as shown above) by making clever use of nested  loops.
Separate each triangle from the next by three horizontal spaces. [Hint: One  loop should control the row number.
Its nested  loops should calculate from the row number the appropriate number of asterisks and spaces for each of the four patterns.]
'''

for i in range(1,11):
    print(i*'*',(11-i)*' ','   ',(11-i)*'*',i*' ','   ',(i)*' ',(11-i)*'*','   ',(11-i)*' ',(i)*'*')

#3.19
'''
3.19(Brute-Force Computing: Pythagorean Triples)
A right triangle can have sides that are all integers.
The set of three integer values for the sides of a right triangle is called a Pythagorean triple.
These three sides must satisfy the relationship that the sum of the squares of two of the sides is equal to the square of the hypotenuse.
Find all Pythagorean triples for ,  and  (such as 3, 4 and 5) all no larger than 20. Use a triple-nested -loop that tries all possibilities.
This is an example of “brute-force” computing.
You’ll learn in more advanced computer science courses that there are many interesting problems for which there is no known algorithmic approach other than sheer brute force.'''

a = 0
b = 0
c = 0

for a in range(1,20):
  for b in range(1,20):
    for c in range(1,20):
      if a**2 + b**2 == c**2:
        print(a, b, c)

#3.20
'''(Binary-to-Decimal Conversion)
Input an integer containing 0s and 1s (i.e., a “binary” integer) and display its decimal equivalent.
The online appendix, “Number Systems,” discusses the binary number system.
[Hint: Use the modulus and division operators to pick off the “binary” number’s digits one at a time from right to left.
Just as in the decimal number system, where the rightmost digit has the positional value 1 and the next digit to the left has the positional value 10, then 100, then 1000, etc.
, in the binary number system, the rightmost digit has the positional value 1, the next digit to the left has the positional value 2, then 4, then 8, etc.
Thus, the decimal number 234 can be interpreted as '''



binary = input('Enter a binary number: ').strip()

decimal = 0
length = len(binary)
for i in range(length):
    bit = int(binary[i])
    power = length - 1 - i
    decimal += bit * (2 ** power)
print(decimal)
